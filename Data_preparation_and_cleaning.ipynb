# %% [markdown]
# # _Data Preparation and Cleaning_

# %% [markdown]
# __While the survey responses contain a lot of information, we are going to limit our analysis to the following areas:__
#
# #### - Demographics
# #### - Programming skills, experience, preferences, etc
# #### - Employment-related information, preferences & opinions

# %% [markdown]
# Firstly, import the __Data_loading__ notebook to use here.

# %%
# %run Data_loading.ipynb

# %% [markdown]
# __Let's select a subset of columns with relavant data for analysis.__

# %%
survey_raw_df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        ...
#        'JobSatPoints_6', 'JobSatPoints_7', 'JobSatPoints_8', 'JobSatPoints_9',
#        'JobSatPoints_10', 'JobSatPoints_11', 'SurveyLength', 'SurveyEase',
#        'ConvertedCompYearly', 'JobSat'],
#       dtype='object', length=114)

# %%
survey_raw_df
# Out:
#        ResponseId                      MainBranch                 Age  \
# 0               1  I am a developer by profession  Under 18 years old
# 1               2  I am a developer by profession     35-44 years old
# 2               3  I am a developer by profession     45-54 years old
# 3               4           I am learning to code     18-24 years old
# 4               5  I am a developer by profession     18-24 years old
# ...           ...                             ...                 ...
# 65432       65433  I am a developer by profession     18-24 years old
# 65433       65434  I am a developer by profession     25-34 years old
# 65434       65435  I am a developer by profession     25-34 years old
# 65435       65436  I am a developer by profession     18-24 years old
# 65436       65437     I code primarily as a hobby     18-24 years old
#
#                 Employment                            RemoteWork   Check  \
# 0      Employed, full-time                                Remote  Apples
# 1      Employed, full-time                                Remote  Apples
# 2      Employed, full-time                                Remote  Apples
# 3       Student, full-time                                   NaN  Apples
# 4       Student, full-time                                   NaN  Apples
# ...                    ...                                   ...     ...
# 65432  Employed, full-time                                Remote  Apples
# 65433  Employed, full-time                                Remote  Apples
# 65434  Employed, full-time                             In-person  Apples
# 65435  Employed, full-time  Hybrid (some remote, some in-person)  Apples
# 65436   Student, full-time                                   NaN  Apples
#
#                                         CodingActivities  \
# 0                                                  Hobby
# 1      Hobby;Contribute to open-source projects;Other...
# 2      Hobby;Contribute to open-source projects;Other...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 65432                      Hobby;School or academic work
# 65433           Hobby;Contribute to open-source projects
# 65434                                              Hobby
# 65435  Hobby;Contribute to open-source projects;Profe...
# 65436                                                NaN
#
#                                                  EdLevel  \
# 0                              Primary/elementary school
# 1           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3      Some college/university study without earning ...
# 4      Secondary school (e.g. American high school, G...
# ...                                                  ...
# 65432       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65433                                                NaN
# 65434       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65435  Secondary school (e.g. American high school, G...
# 65436                                                NaN
#
#                                                LearnCode  \
# 0                                 Books / Physical media
# 1      Books / Physical media;Colleague;On the job tr...
# 2      Books / Physical media;Colleague;On the job tr...
# 3      Other online resources (e.g., videos, blogs, f...
# 4      Other online resources (e.g., videos, blogs, f...
# ...                                                  ...
# 65432  On the job training;School (i.e., University, ...
# 65433                                                NaN
# 65434  Other online resources (e.g., videos, blogs, f...
# 65435  On the job training;Other online resources (e....
# 65436                                                NaN
#
#                                          LearnCodeOnline  ... JobSatPoints_6  \
# 0                                                    NaN  ...            NaN
# 1      Technical documentation;Blogs;Books;Written Tu...  ...            0.0
# 2      Technical documentation;Blogs;Books;Written Tu...  ...            NaN
# 3      Stack Overflow;How-to videos;Interactive tutorial  ...            NaN
# 4      Technical documentation;Blogs;Written Tutorial...  ...            NaN
# ...                                                  ...  ...            ...
# 65432                                                NaN  ...            NaN
# 65433                                                NaN  ...            NaN
# 65434  Technical documentation;Stack Overflow;Social ...  ...            NaN
# 65435  Technical documentation;Blogs;Written Tutorial...  ...            0.0
# 65436                                                NaN  ...            NaN
#
#       JobSatPoints_7 JobSatPoints_8 JobSatPoints_9 JobSatPoints_10  \
# 0                NaN            NaN            NaN             NaN
# 1                0.0            0.0            0.0             0.0
# 2                NaN            NaN            NaN             NaN
# 3                NaN            NaN            NaN             NaN
# 4                NaN            NaN            NaN             NaN
# ...              ...            ...            ...             ...
# 65432            NaN            NaN            NaN             NaN
# 65433            NaN            NaN            NaN             NaN
# 65434            NaN            NaN            NaN             NaN
# 65435            0.0            0.0            0.0             0.0
# 65436            NaN            NaN            NaN             NaN
#
#       JobSatPoints_11           SurveyLength SurveyEase ConvertedCompYearly  \
# 0                 NaN                    NaN        NaN                 NaN
# 1                 0.0                    NaN        NaN                 NaN
# 2                 NaN  Appropriate in length       Easy                 NaN
# 3                 NaN               Too long       Easy                 NaN
# 4                 NaN              Too short       Easy                 NaN
# ...               ...                    ...        ...                 ...
# 65432             NaN                    NaN        NaN                 NaN
# 65433             NaN                    NaN        NaN                 NaN
# 65434             NaN                    NaN        NaN                 NaN
# 65435             0.0                    NaN        NaN                 NaN
# 65436             NaN                    NaN        NaN                 NaN
#
#       JobSat
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 65432    NaN
# 65433    NaN
# 65434    NaN
# 65435    NaN
# 65436    NaN
#
# [65437 rows x 114 columns]

# %%
survey_selected_columns = [
    # Demograhpics
    'Country',
    'Age',
    'EdLevel',
    #Programming experience
    'LearnCode',
    'YearsCode',
    'YearsCodePro',
    'LanguageHaveWorkedWith',
    'WebframeHaveWorkedWith',
    'AIToolCurrently Using',
    #Employment related stuff
    'Employment',
    'RemoteWork',
    'DevType',
    'JobSat',
    'Industry',
]

schema_selected_columns = [
    # Demograhpics
    'Country',
    'Age',
    'EdLevel',
    #Programming experience
    'LearnCode',
    'YearsCode',
    'YearsCodePro',
    'Language',
    'Webframe',
    'AITool',
    #Employment related stuff
    'Employment',
    'RemoteWork',
    'DevType',
    'JobSat',
    'Industry',
]

# %%
len(survey_selected_columns)
# Out:
# 18

# %%
len(schema_selected_columns)
# Out:
# 15

# %% [markdown]
# Let's extract a copy of data from these columns into a new data frame __'survey_df'__, which we can continue to modify further without affecting the original data frame.

# %%
survey_df = survey_raw_df[survey_selected_columns].copy()

# %%
schema = schema_raw[schema_selected_columns]

# %% [markdown]
# Let's view some basic information about the data frame.

# %%
survey_df.shape
# Out:
# (65437, 18)

# %%
schema.shape
# Out:
# (15,)

# %%
survey_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65437 entries, 0 to 65436
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        58930 non-null  object
#  1   Age                            65437 non-null  object
#  2   EdLevel                        60784 non-null  object
#  3   LearnCode                      60488 non-null  object
#  4   YearsCode                      59869 non-null  object
#  5   YearsCodePro                   51610 non-null  object
#  6   LanguageHaveWorkedWith         59745 non-null  object
#  7   LanguageWantToWorkWith         55752 non-null  object
#  8   WebframeHaveWorkedWith         45161 non-null  object
#  9   WebframeWantToWorkWith         38535 non-null  object
#  10  AIToolCurrently Using          35072 non-null  object
#  11  AIToolInterested in Using      30691 non-null  object
#  12  AIToolNot interested in Using  24414 non-null  object
#  13  Employment                     65437 non-null  object
#  14  RemoteWork                     54806 non-null  object
#  15  DevType                        59445 non-null  object
#  16  JobSat                         29126 non-null  float64
#  17  Industry                       28858 non-null  object
# dtypes: float64(1), object(17)
# memory usage: 9.0+ MB

# %% [markdown]
# Most columns have the data type __objects__, either because they contains values of different types, or they contain empty values, which are represented using __NaN__. It appears that some of the columns contains some empty values, since the Not-Null count for many columns is lower than the total number of rows(65437).

# %% [markdown]
# We'll have to deal with empty values and manually adjust the data type for each column on a case-by-case basis.

# %% [markdown]
# Only two one column has dtype as numeric column(JobSat), even though there are few other columns which have mostly numeric values. To make our analysis earsier, let's convert some other columns into numeric data types, while ignoring any non-numeric value.

# %%
schema.YearsCode    # questions
# Out:
# 'Including any education, how many years have you been coding in total?'

# %%
survey_df.YearsCode.unique()    # unique answers
# Out:
# array([nan, '20', '37', '4', '9', '10', '7', '1', '15', '30', '31', '6',
#        '12', '22', '5', '36', '25', '44', '24', '18', '3', '8',
#        'More than 50 years', '11', '29', '40', '39', '2', '42', '34',
#        '19', '35', '16', '33', '13', '23', '14', '28', '17', '21', '43',
#        '46', '26', '32', '41', '45', '27', '38', '50', '48', '47',
#        'Less than 1 year', '49'], dtype=object)

# %%
schema.YearsCodePro
# Out:
# 'NOT including education, how many years have you coded professionally (as a part of your work)?'

# %%
survey_df.YearsCodePro.unique()
# Out:
# array([nan, '17', '27', '7', '11', '25', '12', '10', '3',
#        'Less than 1 year', '18', '37', '15', '20', '6', '2', '16', '8',
#        '14', '4', '45', '1', '24', '29', '5', '30', '26', '9', '33', '13',
#        '35', '23', '22', '31', '19', '21', '28', '34', '32', '40', '50',
#        '39', '44', '42', '41', '36', '38', 'More than 50 years', '43',
#        '47', '48', '46', '49'], dtype=object)

# %%
survey_df['YearsCode'] = pd.to_numeric(survey_df.YearsCode, errors='coerce')
survey_df['YearsCodePro'] = pd.to_numeric(survey_df.YearsCodePro, errors='coerce')

# %% [markdown]
# Let's now see some __basic statistics__ about the numeric columns.

# %%
survey_df.describe()
# Out:
#           YearsCode  YearsCodePro        JobSat
# count  59046.000000  48704.000000  29126.000000
# mean      14.175998     10.739652      6.935041
# std       10.361047      8.935175      2.088259
# min        1.000000      1.000000      0.000000
# 25%        6.000000      4.000000      6.000000
# 50%       11.000000      8.000000      7.000000
# 75%       20.000000     15.000000      8.000000
# max       50.000000     50.000000     10.000000

# %% [markdown]
# These are only three numeric value columns and the data is almost cleaned and ready for the analysis. Let's look at the sample of rows from the data frame.

# %%
survey_df.sample(10)
# Out:
#                         Country                 Age  \
# 17922                 Australia     35-44 years old
# 565    United States of America     35-44 years old
# 51323                     Kenya     18-24 years old
# 25246                     India  Under 18 years old
# 62543                     Spain     35-44 years old
# 14883               Netherlands  Under 18 years old
# 20649                     India     25-34 years old
# 45870               New Zealand     35-44 years old
# 48468  United States of America     55-64 years old
# 50614                 Argentina     35-44 years old
#
#                                                  EdLevel  \
# 17922       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 565                  Associate degree (A.A., A.S., etc.)
# 51323  Some college/university study without earning ...
# 25246  Secondary school (e.g. American high school, G...
# 62543  Secondary school (e.g. American high school, G...
# 14883  Secondary school (e.g. American high school, G...
# 20649    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 45870     Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 48468  Secondary school (e.g. American high school, G...
# 50614  Some college/university study without earning ...
#
#                                                LearnCode  YearsCode  \
# 17922  Books / Physical media;On the job training;Oth...       24.0
# 565    Books / Physical media;Other online resources ...       15.0
# 51323                            Other (please specify):        1.0
# 25246  Other online resources (e.g., videos, blogs, f...        NaN
# 62543     Books / Physical media;Other (please specify):        9.0
# 14883  Books / Physical media;Other online resources ...        6.0
# 20649  On the job training;Other online resources (e....        5.0
# 45870  Other online resources (e.g., videos, blogs, f...        6.0
# 48468  On the job training;Other online resources (e....       45.0
# 50614  Books / Physical media;Other online resources ...       15.0
#
#        YearsCodePro                             LanguageHaveWorkedWith  \
# 17922          20.0                       Bash/Shell (all shells);Java
# 565            15.0  C#;HTML/CSS;PowerShell;Python;SQL;VBA;Visual B...
# 51323           NaN                                      HTML/CSS;Java
# 25246           NaN        C;C++;HTML/CSS;JavaScript;MATLAB;Python;SQL
# 62543           7.0  Bash/Shell (all shells);Go;HTML/CSS;JavaScript...
# 14883           NaN  Bash/Shell (all shells);HTML/CSS;JavaScript;Ko...
# 20649           3.0                           HTML/CSS;Java;JavaScript
# 45870           6.0                                              R;SQL
# 48468          26.0              C#;HTML/CSS;JavaScript;PowerShell;SQL
# 50614           5.0  Bash/Shell (all shells);Elixir;Go;HTML/CSS;Jav...
#
#                                   LanguageWantToWorkWith  \
# 17922                              Assembly;C++;GDScript
# 565                               C#;Visual Basic (.Net)
# 51323                         JavaScript;Kotlin;PHP;Rust
# 25246  Bash/Shell (all shells);C;C++;Elixir;Go;Java;J...
# 62543                Bash/Shell (all shells);Go;Rust;SQL
# 14883  Bash/Shell (all shells);C;Haskell;HTML/CSS;Pyt...
# 20649                                             Kotlin
# 45870                                              R;SQL
# 48468              C#;HTML/CSS;JavaScript;PowerShell;SQL
# 50614  Bash/Shell (all shells);Elixir;HTML/CSS;JavaSc...
#
#                    WebframeHaveWorkedWith  \
# 17922                                 NaN
# 565                                Blazor
# 51323                               Yii 2
# 25246                              jQuery
# 62543      Laravel;Node.js;Symfony;Vue.js
# 14883                        Flask;jQuery
# 20649                  jQuery;Spring Boot
# 45870                                 NaN
# 48468  ASP.NET;ASP.NET CORE;Blazor;jQuery
# 50614                             Phoenix
#
#                                   WebframeWantToWorkWith  \
# 17922                                                NaN
# 565                                                  NaN
# 51323                  Laravel;Node.js;React;Spring Boot
# 25246  Angular;AngularJS;ASP.NET;ASP.NET CORE;Django;...
# 62543                                                NaN
# 14883                                                NaN
# 20649                            Angular;AngularJS;React
# 45870                                                NaN
# 48468                        ASP.NET;ASP.NET CORE;Blazor
# 50614                                            Phoenix
#
#                                    AIToolCurrently Using  \
# 17922  Learning about a codebase;Writing code;Documen...
# 565          Documenting code;Debugging and getting help
# 51323                      Project planning;Testing code
# 25246  Project planning;Writing code;Testing code;Sea...
# 62543  Learning about a codebase;Search for answers;G...
# 14883  Writing code;Documenting code;Debugging and ge...
# 20649  Writing code;Debugging and getting help;Search...
# 45870                                                NaN
# 48468                                                NaN
# 50614                          Writing code;Testing code
#
#                                AIToolInterested in Using  \
# 17922  Testing code;Search for answers;Generating con...
# 565                            Learning about a codebase
# 51323                                   Documenting code
# 25246  Learning about a codebase;Documenting code;Deb...
# 62543                                                NaN
# 14883       Learning about a codebase;Search for answers
# 20649  Learning about a codebase;Documenting code;Tes...
# 45870                                                NaN
# 48468                                                NaN
# 50614  Learning about a codebase;Documenting code;Deb...
#
#                            AIToolNot interested in Using  \
# 17922  Project planning;Committing and reviewing code...
# 565    Project planning;Writing code;Testing code;Com...
# 51323                                       Writing code
# 25246                                                NaN
# 62543  Project planning;Writing code;Documenting code...
# 14883  Project planning;Testing code;Committing and r...
# 20649                                   Project planning
# 45870                                                NaN
# 48468                                                NaN
# 50614  Project planning;Generating content or synthet...
#
#                                               Employment  \
# 17922                                Employed, full-time
# 565                                  Employed, full-time
# 51323  Not employed, but looking for work;Not employe...
# 25246                                 Student, part-time
# 62543                                Employed, full-time
# 14883                                 Student, full-time
# 20649                                Employed, full-time
# 45870                                Employed, full-time
# 48468                                Employed, full-time
# 50614                                Employed, full-time
#
#                                  RemoteWork                        DevType  \
# 17922  Hybrid (some remote, some in-person)            Developer, back-end
# 565                                  Remote          Developer, full-stack
# 51323                                   NaN              Developer, mobile
# 25246                                   NaN                        Student
# 62543  Hybrid (some remote, some in-person)            Developer, back-end
# 14883                                   NaN                        Student
# 20649                             In-person          Developer, full-stack
# 45870                             In-person       Data or business analyst
# 48468                                Remote          Developer, full-stack
# 50614                                Remote  Cloud infrastructure engineer
#
#        JobSat                              Industry
# 17922     7.0                                Other:
# 565       NaN                                   NaN
# 51323     NaN                                   NaN
# 25246     NaN                                   NaN
# 62543     7.0                            Healthcare
# 14883     NaN                                   NaN
# 20649     7.0  Computer Systems Design and Services
# 45870     NaN                                   NaN
# 48468     6.0                         Manufacturing
# 50614     7.0                  Software Development

# %% [markdown]
# ### Data preparation and cleaning is complete now the data is ready for the visualization and analysis.
